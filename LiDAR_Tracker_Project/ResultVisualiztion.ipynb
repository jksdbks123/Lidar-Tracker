# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'D:\LiDAR_Data\MidTown\Liberty\2021-12-11-1-0-0\OutputFile\OutputTrajs/Trajctories_0_post.csv') # path to result
plt.figure(figsize=(10,10))
plt.scatter(data.loc[data.Class == 1,'Coord_X_Mea'],data.loc[data.Class == 1,'Coord_Y_Mea'], s = 3, alpha = 0.2,label = 'Veh')
plt.scatter(data.loc[data.Class == 2,'Coord_X_Mea'],data.loc[data.Class == 2,'Coord_Y_Mea'], s = 3, label = 'Ped')
plt.scatter(data.loc[data.Class == 3,'Coord_X_Mea'],data.loc[data.Class == 3,'Coord_Y_Mea'], s = 3,label = 'Cyc')
plt.xlim(-80,80)
plt.ylim(-80,80)
plt.legend(fontsize = 15)
plt.show()

# %%
data = pd.read_csv(r'D:\LiDAR_Data\MidTown\Roundabout\2022-1-20-12-30-0\OutputFile\OutputTrajs/Trajctories_0_post.csv') # path to result
plt.figure(figsize=(10,10))
plt.scatter(data.loc[data.Class == 1,'Coord_X_Mea'],data.loc[data.Class == 1,'Coord_Y_Mea'], s = 3, alpha = 0.2,label = 'Veh')
plt.scatter(data.loc[data.Class == 2,'Coord_X_Mea'],data.loc[data.Class == 2,'Coord_Y_Mea'], s = 3, label = 'Ped')
plt.scatter(data.loc[data.Class == 3,'Coord_X_Mea'],data.loc[data.Class == 3,'Coord_Y_Mea'], s = 3,label = 'Cyc')
plt.xlim(-80,80)
plt.ylim(-80,80)
plt.legend(fontsize = 15)
plt.show()

# %%
p_dy = 0.05
p_dymc = 1-(1-p_dy)**np.arange(1,100)
p_s = 0.98
p_solid = 1-(1-p_s)**np.arange(1,100)

# %%
plt.figure(figsize=(10,5))
plt.plot(p_dymc,label = 'Dynamic')
plt.plot(p_solid,label = 'Solid')
plt.legend(fontsize = 15)
plt.xlabel('Sample Times',fontsize = 15)
plt.ylabel('Probability',fontsize = 15)
plt.show()

# %%
np.arange(1,100)[-10]
# Out:
# 90

# %%
p_dymc
# Out:
# array([0.05      , 0.0975    , 0.142625  , 0.18549375, 0.22621906,
#        0.26490811, 0.3016627 , 0.33657957, 0.36975059, 0.40126306,
#        0.43119991, 0.45963991, 0.48665792, 0.51232502, 0.53670877,
#        0.55987333, 0.58187966, 0.60278568, 0.6226464 , 0.64151408,
#        0.65943837, 0.67646646, 0.69264313, 0.70801098, 0.72261043,
#        0.73647991, 0.74965591, 0.76217311, 0.77406446, 0.78536124,
#        0.79609317, 0.80628852, 0.81597409, 0.82517539, 0.83391662,
#        0.84222079, 0.85010975, 0.85760426, 0.86472405, 0.87148784,
#        0.87791345, 0.88401778, 0.88981689, 0.89532605, 0.90055974,
#        0.90553176, 0.91025517, 0.91474241, 0.91900529, 0.92305502,
#        0.92690227, 0.93055716, 0.9340293 , 0.93732784, 0.94046144,
#        0.94343837, 0.94626645, 0.94895313, 0.95150547, 0.9539302 ,
#        0.95623369, 0.95842201, 0.96050091, 0.96247586, 0.96435207,
#        0.96613446, 0.96782774, 0.96943635, 0.97096454, 0.97241631,
#        0.97379549, 0.97510572, 0.97635043, 0.97753291, 0.97865627,
#        0.97972345, 0.98073728, 0.98170042, 0.9826154 , 0.98348463,
#        0.98431039, 0.98509487, 0.98584013, 0.98654812, 0.98722072,
#        0.98785968, 0.9884667 , 0.98904336, 0.9895912 , 0.99011164,
#        0.99060605, 0.99107575, 0.99152196, 0.99194587, 0.99234857,
#        0.99273114, 0.99309459, 0.99343986, 0.99376786])
